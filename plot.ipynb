# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("output.txt", header=None, names=['x','y','U','V'], sep=r"\s+")

print(df['U'])
# Out:
# 0        0.001106
# 1        0.002918
# 2        0.012802
# 3        0.074115
# 4        0.398412
#            ...
# 12226    0.524879
# 12227    0.670616
# 12228    0.840895
# 12229    0.952350
# 12230    0.987656
# Name: U, Length: 12231, dtype: float64

# %%
Nx, Ny = 151, 81
df['U'].values.reshape(Nx, Ny).T
# Out:
# array([[0.00110564, 0.00110565, 0.00110565, ..., 0.956478  , 0.981629  ,
#         0.993576  ],
#        [0.00291802, 0.00291802, 0.00291803, ..., 0.934681  , 0.970826  ,
#         0.989393  ],
#        [0.0128017 , 0.0128017 , 0.0128018 , ..., 0.891669  , 0.948017  ,
#         0.980154  ],
#        ...,
#        [0.905155  , 0.90571   , 0.907318  , ..., 0.920706  , 0.872276  ,
#         0.840895  ],
#        [0.488009  , 0.490517  , 0.498708  , ..., 0.976815  , 0.962259  ,
#         0.95235   ],
#        [0.125393  , 0.126166  , 0.128848  , ..., 0.99279   , 0.989802  ,
#         0.987656  ]])

# %%
fig, axs = plt.subplots(1,2)
ax = axs[0]
c = ax.pcolor(df['U'].values.reshape(Nx, Ny).T)
ax.set_title('U value')
fig.colorbar(c, ax=ax)

ax = axs[1]
c = ax.pcolor(df['V'].values.reshape(Nx, Ny).T)
ax.set_title('V value')
fig.colorbar(c, ax=ax)
fig.tight_layout()
fig.suptitle(f"Iterating for Nx={Nx}, Ny={Ny}\n")
plt.savefig(f"test1.png")
