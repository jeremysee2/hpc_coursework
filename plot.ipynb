# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("output.txt", header=None, names=['x','y','U','V'], sep=r"\s+")

print(df['U'])
# Out:
# 0        0.010235
# 1        0.011178
# 2        0.013211
# 3        0.016640
# 4        0.021986
#            ...
# 62996    0.917500
# 62997    0.882477
# 62998    0.822085
# 62999    0.704580
# 63000    0.449286
# Name: U, Length: 63001, dtype: float64

# %%
Nx, Ny = 251, 251
df['U'].values.reshape(Nx, Ny).T
# Out:
# array([[1.02345e-02, 2.26599e-02, 6.10411e-02, ..., 6.75731e-01,
#         5.82618e-01, 5.23860e-01],
#        [1.11785e-02, 2.45838e-02, 6.57260e-02, ..., 6.76202e-01,
#         5.86201e-01, 5.29818e-01],
#        [1.32108e-02, 2.87004e-02, 7.56498e-02, ..., 6.79421e-01,
#         5.95807e-01, 5.44105e-01],
#        ...,
#        [4.77148e-04, 4.97384e-04, 5.35145e-04, ..., 7.84625e-01,
#         8.09470e-01, 8.22085e-01],
#        [4.52070e-04, 4.66261e-04, 4.92142e-04, ..., 6.75074e-01,
#         6.94576e-01, 7.04580e-01],
#        [2.99210e-04, 3.05954e-04, 3.17931e-04, ..., 4.29575e-01,
#         4.42575e-01, 4.49286e-01]])

# %%
fig, axs = plt.subplots(1,2)
ax = axs[0]
c = ax.pcolor(df['U'].values.reshape(Nx, Ny).T)
ax.set_title('U value')
fig.colorbar(c, ax=ax)

ax = axs[1]
c = ax.pcolor(df['V'].values.reshape(Nx, Ny).T)
ax.set_title('V value')
fig.colorbar(c, ax=ax)
fig.tight_layout()
fig.suptitle(f"Iterating for Nx={Nx}, Ny={Ny}\n")
# plt.savefig(f"test1.png")
# Out:
# Text(0.5, 0.98, 'Iterating for Nx=251, Ny=251\n')
