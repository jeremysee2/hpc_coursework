# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("output.txt", header=None, names=['x','y','U','V'], sep=r"\s+")

print(df['U'])
# Out:
# 0        4.607770e-08
# 1        4.587370e-08
# 2        4.461220e-08
# 3        4.118920e-08
# 4        3.520700e-08
#              ...
# 10196    4.369450e-11
# 10197    8.910620e-12
# 10198    1.779820e-12
# 10199    3.519860e-13
# 10200    8.101090e-14
# Name: U, Length: 10201, dtype: float64

# %%
df['U'].values.reshape(101,101).T
# Out:
# array([[4.60777e-08, 4.40556e-08, 3.99752e-08, ..., 7.84237e-01,
#         2.82692e-01, 7.74985e-02],
#        [4.58737e-08, 4.36727e-08, 3.93460e-08, ..., 8.61064e-01,
#         4.31513e-01, 1.45569e-01],
#        [4.46122e-08, 4.21880e-08, 3.75865e-08, ..., 9.32621e-01,
#         7.04375e-01, 3.58041e-01],
#        ...,
#        [9.23571e-13, 1.03798e-12, 1.27408e-12, ..., 2.08468e-11,
#         5.56430e-12, 1.77982e-12],
#        [7.47407e-13, 8.51594e-13, 1.06893e-12, ..., 4.12534e-12,
#         1.10035e-12, 3.51986e-13],
#        [6.62117e-13, 7.60747e-13, 9.67806e-13, ..., 9.49158e-13,
#         2.52981e-13, 8.10109e-14]])

# %%
plt.pcolor(df['U'].values.reshape(101,101).T)

# %%
plt.pcolor(df['V'].values.reshape(101,101).T)
